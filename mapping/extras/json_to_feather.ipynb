# %% [markdown]
# ## Transforming JSON raw data acquired to feather

# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
# Correct code for a standard JSON array
df = pd.read_json(r"C:\Users\HV\Desktop\bruno_work\save_electrospray\experiments\experiment_0.json")

# %%
df=df.T
df

# %%
df

# %%
df = df.reset_index()

# %%
df

# %%
df.to_feather(r"C:\Users\HV\Desktop\bruno_work\save_electrospray\data.feather")
